# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from agave.app import Agave

# %%
agave = Agave()
# Out:
# {'graph_db_uri': 'bolt://127.0.0.1:7687', 'graph_db_user': 'neo4j', 'graph_db_password': 'agave', 'database_string': 'mariadb+pymysql://agave:agave_password@127.0.0.1:13306/agave'}

# %%
agave.initialize()
# Out:
# Connected to graph db
# Connected to metadata table
# Connected to paper cache
# /home/frinve/Code/agave/agave/engine/engine.py:73: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self.counted_uids = pd.Series().value_counts()

# %%
lines=['SARS-CoV-2<>Lung<>year',
'Age<>year<>Therapeutic procedure']
agave.graphical_abstract.load(lines)
# Out:
# ['SARS-CoV-2', 'Lung', 'year']
# ['Age', 'year', 'Therapeutic procedure']

# %%
agave.find_name('effect')
# Out:
# [{'name': 'poisonous effects', 'umls_id': 'C0243147', 'frequency': 3}, {'name': 'aspects of adverse effects', 'umls_id': 'C0001688', 'frequency': 10392}, {'name': 'Oral bisphosphonates causing adverse effects in therapeutic use', 'umls_id': 'C1955565', 'frequency': 7}, {'name': 'Ineffective breathing pattern', 'umls_id': 'C1999000', 'frequency': 3}, {'name': 'Toxic effect of heavy metal', 'umls_id': 'C0274869', 'frequency': 3}, {'name': 'Toxic effect of strychnine', 'umls_id': 'C0274892', 'frequency': 2}, {'name': 'Toxic effect of aflatoxin', 'umls_id': 'C0274911', 'frequency': 1}, {'name': 'Idiosyncratic drug effect', 'umls_id': 'C0277580', 'frequency': 1}, {'name': 'cancer psychosocial effects', 'umls_id': 'C0280957', 'frequency': 208}, {'name': 'No-Observed-Effect Level', 'umls_id': 'C0282618', 'frequency': 2}, {'name': 'No-Observed-Adverse-Effect Level', 'umls_id': 'C0282619', 'frequency': 20}, {'name': 'Cohort Effect', 'umls_id': 'C0009246', 'frequency': 307}, {'name': 'Cost Effectiveness', 'umls_id': 'C0010181', 'frequency': 5545}, {'name': 'Immune effector cell', 'umls_id': 'C0312740', 'frequency': 266}, {'name': 'effector caspase activity', 'umls_id': 'C1150131', 'frequency': 10}, {'name': 'Double Effect Principle', 'umls_id': 'C2350028', 'frequency': 2}, {'name': 'Chromosomal Position Effects', 'umls_id': 'C2350240', 'frequency': 1}, {'name': 'Cytopathogenic Effect, Viral', 'umls_id': 'C0010827', 'frequency': 973}, {'name': 'Doppler Effect', 'umls_id': 'C0013041', 'frequency': 10}, {'name': 'Effect Modifier, Epidemiologic', 'umls_id': 'C0013675', 'frequency': 160}, {'name': 'Actual Effective Cognition', 'umls_id': 'C2712133', 'frequency': 33}, {'name': 'Comparative Effectiveness Research', 'umls_id': 'C2718022', 'frequency': 142}, {'name': 'Halo Effect', 'umls_id': 'C0018538', 'frequency': 6}, {'name': 'Hawthorne Effect', 'umls_id': 'C0018620', 'frequency': 9}, {'name': 'Healthy Worker Effect', 'umls_id': 'C0018766', 'frequency': 30}, {'name': 'Physiological Effects of Drugs', 'umls_id': 'C1258063', 'frequency': 35}, {'name': 'Effects of chemotherapy', 'umls_id': 'C1264521', 'frequency': 1}, {'name': 'Off-resonance Effect', 'umls_id': 'C2828093', 'frequency': 3}, {'name': 'Cone-beam Effect Artifact', 'umls_id': 'C2828108', 'frequency': 1}, {'name': 'Effect', 'umls_id': 'C1280500', 'frequency': 107708}, {'name': 'Effectiveness', 'umls_id': 'C1280519', 'frequency': 114581}, {'name': 'Late effects of poliomyelitis', 'umls_id': 'C0362050', 'frequency': 1}, {'name': 'Personal effects', 'umls_id': 'C1285507', 'frequency': 14}, {'name': 'metabolic effects', 'umls_id': 'C2945675', 'frequency': 6}, {'name': 'oral effects', 'umls_id': 'C2945677', 'frequency': 4}, {'name': 'pulmonary effects', 'umls_id': 'C2945684', 'frequency': 25}, {'name': 'thyroid effects', 'umls_id': 'C2945699', 'frequency': 1}, {'name': 'No effect', 'umls_id': 'C1301751', 'frequency': 343}, {'name': 'Longterm Effects', 'umls_id': 'C0023983', 'frequency': 18}, {'name': 'Bothered By Side Effects of Treatment', 'umls_id': 'C2984047', 'frequency': 1}, {'name': 'medication action/side effects', 'umls_id': 'C0392325', 'frequency': 2}, {'name': 'Ineffective erythropoiesis', 'umls_id': 'C0392708', 'frequency': 1}, {'name': 'Health Care Provider Effective Date Range', 'umls_id': 'C2986041', 'frequency': 1}, {'name': 'Study Resource Effective Date Range', 'umls_id': 'C2986335', 'frequency': 1}, {'name': 'p53 Apoptosis Effector Related to PMP-22', 'umls_id': 'C2986661', 'frequency': 6}, {'name': 'Partial Volume Effect', 'umls_id': 'C2986794', 'frequency': 7}, {'name': 'Effective Half-life', 'umls_id': 'C2986842', 'frequency': 2}, {'name': 'Ineffective tissue perfusion', 'umls_id': 'C1328773', 'frequency': 21}, {'name': 'death effector domain binding', 'umls_id': 'C3159080', 'frequency': 1}, {'name': 'Emetic Effect', 'umls_id': 'C3178735', 'frequency': 1}, {'name': 'Effector B Cells', 'umls_id': 'C3178739', 'frequency': 107}, {'name': 'Antimutagenic Effect', 'umls_id' ...
# [{'name': 'poisonous effects', 'umls_id': 'C0243147', 'frequency': 3},
#  {'name': 'aspects of adverse effects',
#   'umls_id': 'C0001688',
#   'frequency': 10392},
#  {'name': 'Oral bisphosphonates causing adverse effects in therapeutic use',
#   'umls_id': 'C1955565',
#   'frequency': 7},
#  {'name': 'Ineffective breathing pattern',
#   'umls_id': 'C1999000',
#   'frequency': 3},
#  {'name': 'Toxic effect of heavy metal',
#   'umls_id': 'C0274869',
#   'frequency': 3},
#  {'name': 'Toxic effect of strychnine', 'umls_id': 'C0274892', 'frequency': 2},
#  {'name': 'Toxic effect of aflatoxin', 'umls_id': 'C0274911', 'frequency': 1},
#  {'name': 'Idiosyncratic drug effect', 'umls_id': 'C0277580', 'frequency': 1},
#  {'name': 'cancer psychosocial effects',
#   'umls_id': 'C0280957',
#   'frequency': 208},
#  {'name': 'No-Observed-Effect Level', 'umls_id': 'C0282618', 'frequency': 2},
#  {'name': 'No-Observed-Adverse-Effect Level',
#   'umls_id': 'C0282619',
#   'frequency': 20},
#  {'name': 'Cohort Effect', 'umls_id': 'C0009246', 'frequency': 307},
#  {'name': 'Cost Effectiveness', 'umls_id': 'C0010181', 'frequency': 5545},
#  {'name': 'Immune effector cell', 'umls_id': 'C0312740', 'frequency': 266},
#  {'name': 'effector caspase activity', 'umls_id': 'C1150131', 'frequency': 10},
#  {'name': 'Double Effect Principle', 'umls_id': 'C2350028', 'frequency': 2},
#  {'name': 'Chromosomal Position Effects',
#   'umls_id': 'C2350240',
#   'frequency': 1},
#  {'name': 'Cytopathogenic Effect, Viral',
#   'umls_id': 'C0010827',
#   'frequency': 973},
#  {'name': 'Doppler Effect', 'umls_id': 'C0013041', 'frequency': 10},
#  {'name': 'Effect Modifier, Epidemiologic',
#   'umls_id': 'C0013675',
#   'frequency': 160},
#  {'name': 'Actual Effective Cognition',
#   'umls_id': 'C2712133',
#   'frequency': 33},
#  {'name': 'Comparative Effectiveness Research',
#   'umls_id': 'C2718022',
#   'frequency': 142},
#  {'name': 'Halo Effect', 'umls_id': 'C0018538', 'frequency': 6},
#  {'name': 'Hawthorne Effect', 'umls_id': 'C0018620', 'frequency': 9},
#  {'name': 'Healthy Worker Effect', 'umls_id': 'C0018766', 'frequency': 30},
#  {'name': 'Physiological Effects of Drugs',
#   'umls_id': 'C1258063',
#   'frequency': 35},
#  {'name': 'Effects of chemotherapy', 'umls_id': 'C1264521', 'frequency': 1},
#  {'name': 'Off-resonance Effect', 'umls_id': 'C2828093', 'frequency': 3},
#  {'name': 'Cone-beam Effect Artifact', 'umls_id': 'C2828108', 'frequency': 1},
#  {'name': 'Effect', 'umls_id': 'C1280500', 'frequency': 107708},
#  {'name': 'Effectiveness', 'umls_id': 'C1280519', 'frequency': 114581},
#  {'name': 'Late effects of poliomyelitis',
#   'umls_id': 'C0362050',
#   'frequency': 1},
#  {'name': 'Personal effects', 'umls_id': 'C1285507', 'frequency': 14},
#  {'name': 'metabolic effects', 'umls_id': 'C2945675', 'frequency': 6},
#  {'name': 'oral effects', 'umls_id': 'C2945677', 'frequency': 4},
#  {'name': 'pulmonary effects', 'umls_id': 'C2945684', 'frequency': 25},
#  {'name': 'thyroid effects', 'umls_id': 'C2945699', 'frequency': 1},
#  {'name': 'No effect', 'umls_id': 'C1301751', 'frequency': 343},
#  {'name': 'Longterm Effects', 'umls_id': 'C0023983', 'frequency': 18},
#  {'name': 'Bothered By Side Effects of Treatment',
#   'umls_id': 'C2984047',
#   'frequency': 1},
#  {'name': 'medication action/side effects',
#   'umls_id': 'C0392325',
#   'frequency': 2},
#  {'name': 'Ineffective erythropoiesis', 'umls_id': 'C0392708', 'frequency': 1},
#  {'name': 'Health Care Provider Effective Date Range',
#   'umls_id': 'C2986041',
#   'frequency': 1},
#  {'name': 'Study Resource Effective Date Range',
#   'umls_id': 'C2986335',
#   'frequency': 1},
#  {'name': 'p53 Apoptosis Effector Related to PMP-22',
#   'umls_id': 'C2986661',
#   'frequency': 6},
#  {'name': 'Partial Volume Effect', 'umls_id': 'C2986794', 'frequency': 7},
#  {'name': 'Effective Half-life', 'umls_id': 'C2986842', 'frequency': 2},
#  {'name': 'Ineffective tissue perfusion',
#   'umls_id': 'C1328773',
#   'frequency': 21},
#  {'name': 'death effector domain binding',
#   'umls_id': 'C3159080',
#   'frequency': 1},
#  {'name': 'Emetic Effect', 'umls_id': 'C3178735', 'frequency': 1},
#  {'name': 'Effector B Cells', 'umls_id': 'C3178739', 'frequency': 107},
#  {'name': 'Antimutagenic Effect', 'umls_id': 'C3178743', 'frequency': 1},
#  {'name': 'Anticarcinogenic Effect', 'umls_id': 'C3178744', 'frequency': 2},
#  {'name': 'Performance-Enhancing Effect',
#   'umls_id': 'C3178747',
#   'frequency': 4},
#  {'name': 'Antipyretic Effect', 'umls_id': 'C3178748', 'frequency': 2},
#  {'name': 'Fertility Effect', 'umls_id': 'C3178752', 'frequency': 3},
#  {'name': 'Glucocorticoid Effect', 'umls_id': 'C3179152', 'frequency': 2},
#  {'name': 'Photosensitizing Effect', 'umls_id': 'C3179153', 'frequency': 1},
#  {'name': 'Hypnotic Effect', 'umls_id': 'C3179158', 'frequency': 2},
#  {'name': 'Sedative Effect', 'umls_id': 'C3179159', 'frequency': 15},
#  {'name': 'Neuromuscular Effect', 'umls_id': 'C3179228', 'frequency': 3},
#  {'name': 'Anti-Angiogenesis Effect', 'umls_id': 'C3179230', 'frequency': 2},
#  {'name': 'Antispasmodic Effect', 'umls_id': 'C3179242', 'frequency': 1},
#  {'name': 'Radiation-Sensitizing Effect',
#   'umls_id': 'C3179280',
#   'frequency': 3},
#  {'name': 'Anti-Androgen Effect', 'umls_id': 'C3179299', 'frequency': 2},
#  {'name': 'Anesthetic Effect', 'umls_id': 'C3179301', 'frequency': 6},
#  {'name': 'Antioxidant Effect', 'umls_id': 'C3179302', 'frequency': 183},
#  {'name': 'Aphrodisiac Effect', 'umls_id': 'C3179304', 'frequency': 2},
#  {'name': 'Natriuretic Effect', 'umls_id': 'C3179308', 'frequency': 2},
#  {'name': 'Anabolic Effect', 'umls_id': 'C3179309', 'frequency': 9},
#  {'name': 'Antidiuretic Effect', 'umls_id': 'C3179353', 'frequency': 1},
#  {'name': 'Bronchodilator Effect', 'umls_id': 'C3179385', 'frequency': 11},
#  {'name': 'Sympatholytic Effect', 'umls_id': 'C3179395', 'frequency': 3},
#  {'name': 'Anti-Anxiety Effect', 'umls_id': 'C3179404', 'frequency': 21},
#  {'name': 'Contraceptive Effect', 'umls_id': 'C3179447', 'frequency': 1},
#  {'name': 'Endocrine Disruptor Effect', 'umls_id': 'C3179454', 'frequency': 2},
#  {'name': 'Cryoprotective Effect', 'umls_id': 'C3179493', 'frequency': 2},
#  {'name': 'Tocolytic Effect', 'umls_id': 'C3179497', 'frequency': 1},
#  {'name': 'Effective refractory period (cardiac conduction)',
#   'umls_id': 'C0428937',
#   'frequency': 1},
#  {'name': 'previously ineffective', 'umls_id': 'C3242035', 'frequency': 1},
#  {'name': 'ineffective', 'umls_id': 'C3242229', 'frequency': 1963},
#  {'name': 'Placebo Effect', 'umls_id': 'C0032041', 'frequency': 22},
#  {'name': 'Late effect of medical intervention',
#   'umls_id': 'C1368999',
#   'frequency': 132},
#  {'name': 'Physiological Effects', 'umls_id': 'C1372798', 'frequency': 164},
#  {'name': 'Change Being Effective', 'umls_id': 'C3273198', 'frequency': 2},
#  {'name': 'Prenatal Exposure Delayed Effects',
#   'umls_id': 'C0033054',
#   'frequency': 14},
#  {'name': 'Food Effect Study', 'umls_id': 'C3274396', 'frequency': 36},
#  {'name': 'Effects of radiation', 'umls_id': 'C0034525', 'frequency': 16},
#  {'name': 'aspects of radiation effects',
#   'umls_id': 'C0034526',
#   'frequency': 146},
#  {'name': 'Satisfied with Treatment Effects',
#   'umls_id': 'C3483274',
#   'frequency': 89},
#  {'name': 'Relative Biological Effectiveness',
#   'umls_id': 'C0035023',
#   'frequency': 111},
#  {'name': 'Effects of vibration', 'umls_id': 'C0452131', 'frequency': 1},
#  {'name': 'Effector T-Lymphocyte', 'umls_id': 'C3641722', 'frequency': 208},
#  {'name': 'Theoretical Effectiveness', 'umls_id': 'C0039777', 'frequency': 7},
#  {'name': 'Nocebo Effect', 'umls_id': 'C3658218', 'frequency': 35},
#  {'name': 'Toxic effect of venom', 'umls_id': 'C0040533', 'frequency': 16},
#  {'name': 'Toxic effect of chemical', 'umls_id': 'C0520761', 'frequency': 5},
#  {'name': 'Anticoagulant effect', 'umls_id': 'C0520996', 'frequency': 19},
#  {'name': 'rebound effect', 'umls_id': 'C0549262', 'frequency': 85},
#  {'name': 'Clinical Effectiveness', 'umls_id': 'C3850123', 'frequency': 441},
#  {'name': 'Treatment/Psychosocial Effects',
#   'umls_id': 'C1458132',
#   'frequency': 2886},
#  {'name': 'Beta Radiation Effect', 'umls_id': 'C1511112', 'frequency': 1},
#  {'name': 'Cost Effective Management', 'umls_id': 'C1511535', 'frequency': 9},
#  {'name': 'Cost-Effectiveness Analysis',
#   'umls_id': 'C1511536',
#   'frequency': 312},
#  {'name': 'Cognitive Side Effects of Cancer Therapy',
#   'umls_id': 'C3899523',
#   'frequency': 1},
#  {'name': 'RHO Effector Domain', 'umls_id': 'C1514650', 'frequency': 55},
#  {'name': 'Sunscreen Effect', 'umls_id': 'C1515055', 'frequency': 3},
#  {'name': 'Anti-inflammatory effect',
#   'umls_id': 'C1515999',
#   'frequency': 1035},
#  {'name': 'Antiemetic Effect', 'umls_id': 'C1516011', 'frequency': 5},
#  {'name': 'Antimicrobial Effect', 'umls_id': 'C1516022', 'frequency': 162},
#  {'name': 'Antipruritic Effect', 'umls_id': 'C1516026', 'frequency': 1},
#  {'name': 'Ceiling Effect', 'umls_id': 'C1516322', 'frequency': 175},
#  {'name': 'Long Term Adverse Effects', 'umls_id': 'C4042798', 'frequency': 2},
#  {'name': 'Healthcare Failure Mode and Effect Analysis',
#   'umls_id': 'C4042853',
#   'frequency': 31},
#  {'name': 'Neurologic Effect', 'umls_id': 'C1518287', 'frequency': 748},
#  {'name': 'Failure Mode and Effect Analysis',
#   'umls_id': 'C4046088',
#   'frequency': 11},
#  {'name': 'Graft vs Leukemia Effect', 'umls_id': 'C0600554', 'frequency': 9},
#  {'name': 'Graft vs Tumor Effect', 'umls_id': 'C0600555', 'frequency': 2},
#  {'name': 'Toxic effect', 'umls_id': 'C0600688', 'frequency': 2884},
#  {'name': 'Warburg Effect', 'umls_id': 'C1520120', 'frequency': 37},
#  {'name': 'Treatment Effectiveness', 'umls_id': 'C0087113', 'frequency': 1532},
#  {'name': 'Effector Memory Immune Cell',
#   'umls_id': 'C4055074',
#   'frequency': 2},
#  {'name': 'Therapeutic Effect', 'umls_id': 'C1527144', 'frequency': 1913},
#  {'name': 'alcohol effect', 'umls_id': 'C0678356', 'frequency': 6},
#  {'name': 'chronic alcohol effect', 'umls_id': 'C0678358', 'frequency': 1},
#  {'name': 'Mass Effect', 'umls_id': 'C4086564', 'frequency': 75},
#  {'name': 'Ineffective airway clearance',
#   'umls_id': 'C0150011',
#   'frequency': 9},
#  {'name': 'income effect', 'umls_id': 'C0680962', 'frequency': 18},
#  {'name': 'substitution effect', 'umls_id': 'C0680963', 'frequency': 1},
#  {'name': 'Death Effector Domain', 'umls_id': 'C4277613', 'frequency': 28},
#  {'name': 'Transcription Activator-Like Effectors',
#   'umls_id': 'C4277620',
#   'frequency': 261},
#  {'name': 'Transcription Activator-Like Effector Nucleases',
#   'umls_id': 'C4277678',
#   'frequency': 21},
#  {'name': 'Radiation Effects', 'umls_id': 'C4281532', 'frequency': 258},
#  {'name': 'Late effect of radiation', 'umls_id': 'C0160814', 'frequency': 31},
#  {'name': 'effect modifier', 'umls_id': 'C0681891', 'frequency': 1},
#  {'name': 'Effects of low temperature', 'umls_id': 'C0161734', 'frequency': 3},
#  {'name': 'effector domain', 'umls_id': 'C0682970', 'frequency': 3},
#  {'name': 'dose-effect curve', 'umls_id': 'C0683161', 'frequency': 1},
#  {'name': 'Effector Memory T-Lymphocyte',
#   'umls_id': 'C4289596',
#   'frequency': 148},
#  {'name': 'regulation of adaptive immune effector response',
#   'umls_id': 'C4327543',
#   'frequency': 1},
#  {'name': 'adaptive immune effector response',
#   'umls_id': 'C4329013',
#   'frequency': 8},
#  {'name': 'Drug effect', 'umls_id': 'C0728866', 'frequency': 319},
#  {'name': 'Drug effect disorder', 'umls_id': 'C0728867', 'frequency': 47},
#  {'name': 'Care for Medication Side Effects',
#   'umls_id': 'C0184617',
#   'frequency': 1},
#  {'name': 'Contraceptive Effectiveness',
#   'umls_id': 'C4505082',
#   'frequency': 10},
#  {'name': 'Worry About Side Effects from Medical Treatments',
#   'umls_id': 'C4525478',
#   'frequency': 1},
#  {'name': 'Effector (disposition)', 'umls_id': 'C4543203', 'frequency': 716},
#  {'name': 'Renal Plasma Flow, Effective',
#   'umls_id': 'C0206088',
#   'frequency': 5},
#  {'name': 'Greenhouse Effect', 'umls_id': 'C0206218', 'frequency': 26},
#  {'name': 'Adverse Effect Mitigation Study',
#   'umls_id': 'C1706601',
#   'frequency': 12209},
#  {'name': 'effect size', 'umls_id': 'C0814843', 'frequency': 1837},
#  {'name': 'prevention effectiveness', 'umls_id': 'C0815149', 'frequency': 4},
#  {'name': 'individual-level effects', 'umls_id': 'C0815261', 'frequency': 5},
#  {'name': 'Neuroprotective Effect', 'umls_id': 'C0815279', 'frequency': 205},
#  {'name': 'Field Effect Transistor Device',
#   'umls_id': 'C1708057',
#   'frequency': 89},
#  {'name': 'Abscopal Effect', 'umls_id': 'C4684448', 'frequency': 21},
#  {'name': 'Carry-over Effect', 'umls_id': 'C4684579', 'frequency': 23},
#  {'name': 'Metastatic Inhibitory Effect',
#   'umls_id': 'C1708997',
#   'frequency': 946},
#  {'name': 'adverse effect due to surgery',
#   'umls_id': 'C0221082',
#   'frequency': 226},
#  {'name': 'Pharmacokinetic Effect', 'umls_id': 'C1709520', 'frequency': 8},
#  {'name': 'Effective Orifice Area', 'umls_id': 'C4687741', 'frequency': 3},
#  {'name': 'Effective Orifice Area Index',
#   'umls_id': 'C4687742',
#   'frequency': 2},
#  {'name': 'Effects of heat', 'umls_id': 'C0221500', 'frequency': 6},
#  {'name': 'Ineffective community coping',
#   'umls_id': 'C0221550',
#   'frequency': 14},
#  {'name': 'Period Effect', 'umls_id': 'C4688485', 'frequency': 28},
#  {'name': 'altitude effects', 'umls_id': 'C0870127', 'frequency': 1},
#  {'name': 'iatrogenic effects', 'umls_id': 'C0870679', 'frequency': 4},
#  {'name': 'noise effects', 'umls_id': 'C0870961', 'frequency': 5},
#  {'name': 'Organizational effectiveness',
#   'umls_id': 'C0871016',
#   'frequency': 14},
#  {'name': 'pygmalion effect', 'umls_id': 'C0871323', 'frequency': 1},
#  {'name': 'Caspases, Effector', 'umls_id': 'C1720985', 'frequency': 3},
#  {'name': 'temperature effects', 'umls_id': 'C0871499', 'frequency': 1},
#  {'name': 'gravitational effects', 'umls_id': 'C0871761', 'frequency': 5},
#  {'name': 'Stroop Effect', 'umls_id': 'C0871925', 'frequency': 1},
#  {'name': 'environmental effects', 'umls_id': 'C0871974', 'frequency': 168},
#  {'name': 'light effects', 'umls_id': 'C0872206', 'frequency': 1},
#  {'name': 'Sympathomimetic Effect', 'umls_id': 'C0877014', 'frequency': 2},
#  {'name': 'Estrogen Effect', 'umls_id': 'C0877035', 'frequency': 6},
#  {'name': 'immune effector process', 'umls_id': 'C1817420', 'frequency': 8},
#  {'name': 'Adverse effects', 'umls_id': 'C0879626', 'frequency': 1303},
#  {'name': 'regulation of immune effector process',
#   'umls_id': 'C1818811',
#   'frequency': 10},
#  {'name': 'negative regulation of immune effector process',
#   'umls_id': 'C1818812',
#   'frequency': 1},
#  {'name': 'No Observable Effect Level',
#   'umls_id': 'C4744964',
#   'frequency': 17},
#  {'name': 'Bohr effect', 'umls_id': 'C0231825', 'frequency': 3},
#  {'name': 'Alcohol Effect Study', 'umls_id': 'C4761544', 'frequency': 1},
#  {'name': 'Diuretic Effect', 'umls_id': 'C0948429', 'frequency': 4},
#  {'name': 'analgesic effect', 'umls_id': 'C0948482', 'frequency': 100},
#  {'name': 'Abnormal proportion of CD4+ effector memory cells',
#   'umls_id': 'C5139094',
#   'frequency': 3},
#  {'name': 'Reduced proportion of CD4+ effector memory T cells',
#   'umls_id': 'C5139095',
#   'frequency': 16},
#  {'name': 'double effect', 'umls_id': 'C0949293', 'frequency': 11},
#  {'name': 'Bystander Effect', 'umls_id': 'C0949629', 'frequency': 112},
#  {'name': 'Unexpected therapeutic effect',
#   'umls_id': 'C0235735',
#   'frequency': 13},
#  {'name': 'overdose effect', 'umls_id': 'C0235822', 'frequency': 2},
#  {'name': 'Statistical Effect Size', 'umls_id': 'C0237589', 'frequency': 3},
#  {'name': 'Position Effect Trial', 'umls_id': 'C5205843', 'frequency': 197},
#  {'name': 'Water Effect Trial', 'umls_id': 'C5205845', 'frequency': 1},
#  {'name': 'Immune Effector Cell Associated Neurotoxicity Syndrome',
#   'umls_id': 'C5206861',
#   'frequency': 32},
#  {'name': 'Immune Effector Encephalopathy - ICE Assessment',
#   'umls_id': 'C5206862',
#   'frequency': 9},
#  {'name': 'Founder Effect', 'umls_id': 'C0242918', 'frequency': 125}]

# %%
agave.graphical_abstract.draw()

# %%
#Choose here the minimum npmi for each segment of the paths
agave.find_graphical_abstract(npmi_thr=0)

# %%
agave.show_found_paths()
# Out:
# SARS-CoV-2-->Lung
# 0 ['Lung<SEP>SARS-CoV-2'] 			 0.118114
# -------------------------
# Lung-->year
# 0 ['Lung<SEP>Pradax', 'year<SEP>Pradax'] 			 0.22181399999999998
# 1 ['Lung<SEP>Abnormality of dental color', 'year<SEP>Abnormality of dental color'] 			 0.22181399999999998
# 2 ['Lung<SEP>magnetic therapy', 'year<SEP>magnetic therapy'] 			 0.22181399999999998
# 3 ['Appetite Disorders<SEP>Lung', 'Appetite Disorders<SEP>year'] 			 0.22181399999999998
# 4 ['Lung<SEP>Fibrinous pleurisy', 'Fibrinous pleurisy<SEP>year'] 			 0.22181399999999998
# 5 ['Lung<SEP>Ductal or Ductular Proliferation', 'year<SEP>Ductal or Ductular Proliferation'] 			 0.22181399999999998
# 6 ['Lung<SEP>TTF1 protein, human', 'year<SEP>TTF1 protein, human'] 			 0.22181399999999998
# 7 ['Lung<SEP>Ground Glass Opacity', 'year<SEP>Ground Glass Opacity'] 			 0.2200164
# 8 ['Lung<SEP>Largactil', 'year<SEP>Largactil'] 			 0.21473399999999998
# 9 ['Lung<SEP>Antero-posterior projection', 'year<SEP>Antero-posterior projection'] 			 0.21473399999999998
# 10 ['Lung<SEP>Reticulin fibrosis', 'Reticulin fibrosis<SEP>year'] 			 0.21473399999999998
# -------------------------
# Age-->year
# 0 ['Age<SEP>year'] 			 0.453121
# -------------------------
# year-->Therapeutic procedure
# 0 ['Conjunctival hemorrhage<SEP>year', 'Conjunctival hemorrhage<SEP>Therapeutic procedure'] 			 0.173429
# 1 ['year<SEP>desloratadine', 'Therapeutic procedure<SEP>desloratadine'] 			 0.173429
# 2 ['year<SEP>magnetic therapy', 'Therapeutic procedure<SEP>magnetic therapy'] 			 0.169375
# 3 ['year<SEP>VBY-825', 'Therapeutic procedure<SEP>VBY-825'] 			 0.169375
# 4 ['year<SEP>Peptoids', 'Therapeutic procedure<SEP>Peptoids'] 			 0.169375
# 5 ['year<SEP>ADRA1B gene', 'Therapeutic procedure<SEP>ADRA1B gene'] 			 0.169375
# 6 ['Appetite Disorders<SEP>year', 'Appetite Disorders<SEP>Therapeutic procedure'] 			 0.169375
# 7 ['year<SEP>Cord Blood Bank', 'Therapeutic procedure<SEP>Cord Blood Bank'] 			 0.169375
# 8 ['year<SEP>Minim - package', 'Therapeutic procedure<SEP>Minim - package'] 			 0.169375
# 9 ['year<SEP>CDA Inhibitor E7727/Decitabine Combination Agent ASTX727', 'Therapeutic procedure<SEP>CDA Inhibitor E7727/Decitabine Combination Agent ASTX727'] 			 0.169375
# 10 ['year<SEP>TTF1 protein, human', 'Therapeutic procedure<SEP>TTF1 protein, human'] 			 0.169375
# -------------------------

# %%
agave.autoselect_path()
# Out:
# SARS-CoV-2-->Lung
# 0 ['Lung<SEP>SARS-CoV-2']
# --------------------------
# Lung-->year
# 0 ['Lung<SEP>Pradax', 'year<SEP>Pradax']
# --------------------------
# Age-->year
# 0 ['Age<SEP>year']
# --------------------------
# year-->Therapeutic procedure
# 0 ['Conjunctival hemorrhage<SEP>year', 'Conjunctival hemorrhage<SEP>Therapeutic procedure']
# --------------------------

# %%
agave.retrieve_papers()

# %%
agave.show_found_papers(5)
# Out:
#    cord_uid                                              title  \
# 0  0ka21kgg  Performance of a rapid SARS-COV-2 serology tes...
# 1  1zqe6r7n  Telomere Shortening and Its Association with C...
# 2  glv2dcyd  Audit of ADHD medication prescription and moni...
# 3  k5v2lzia  Risk factors for developing symptomatic COVID-...
# 4  nd7h0cmq  Non-Invasive Respiratory Support in the Manage...
# 5  ndscdqcb  School Opening Delay Effect on Transmission Dy...
# 6  q3b0xs9j  Health Satisfaction in Health Care between Pat...
# 7  ug53ks5k  Factors Associated with Incarceration in Older...
# 8  xr406wsr  Spinal Cord Ischemia Secondary to Aortic Disse...
#
#                                             abstract  \
# 0  Rapid SARS-COV-2 related serology testing can ...
# 1  Telomeres are localized at the end of chromoso...
# 2  AimsStudies have shown that people with intell...
# 3  BackgroundCOVID-19 pandemic has had a major im...
# 4  Background During peak pandemic period of COVI...
# 5  BACKGROUND: Nonpharmaceutical intervention str...
# 6  Background: Healthcare capacity in Iraq has de...
# 7  BACKGROUND: In the US, the median age of adult...
# 8  Aortic dissection (AD) is a serious condition ...
#
#                            doi  \
# 0  10.1101/2020.10.02.20199083
# 1         10.3390/ijms23010425
# 2                         None
# 3                         None
# 4   10.1016/j.tacc.2021.04.008
# 5    10.3346/jkms.2020.35.e143
# 6   10.37506/ijfmt.v16i1.17436
# 7   10.1007/s11606-021-06897-0
# 8            10.1159/000518197
#
#                                              authors  \
# 0                                     Vemulapati, S.
# 1  Ruiz, Andy; Flores-Gonzalez, Julio; Buendia-Ro...
# 2                        Bansal, Neha Hayat Muzammil
# 3  Minobes-Molina, Eduard; Escribà-Salvans, Anna;...
# 4  Betancur, Adrián Mira; De Pablo Pajares, Angélica
# 5  Kim, Soyoung; Kim, Yae-Jean; Peck, Kyong Ran; ...
# 6  Samad, A. A.; Gli, F. A. A.; Kanbar, C. B.; Ma...
# 7  Garcia-Grossman, Ilana; Kaplan, Lauren; Valle,...
# 8  Elshony, Hosna; Idris, Abdelrahman; Ahmed, Ala...
#
#                                              journal publish_time occurrences  \
# 0                                               None   2020-10-02           1
# 1                                      Int J Mol Sci   2021-12-31           2
# 2                                       BJPsych Open   2021-01-01           2
# 3                                               None   2022-01-01           2
# 4            Trends in Anaesthesia and Critical Care   2021-05-08           2
# 5                                   J Korean Med Sci   2020-04-01           2
# 6  Indian Journal of Forensic Medicine and Toxico...   2022-01-01           4
# 7                                   J Gen Intern Med   2021-06-09           2
# 8                                    Case Rep Neurol   2021-01-01           2
#
#                                  explained_relations
# 0                ['Enhance (action)<SEP>SARS-CoV-2']
# 1      ['Lung<SEP>Enhance (action)', 'Age<SEP>Lung']
# 2                   ['Age<SEP>year', 'Age<SEP>year']
# 3                   ['Age<SEP>year', 'Age<SEP>year']
# 4                   ['Age<SEP>year', 'Age<SEP>year']
# 5                   ['Age<SEP>year', 'Age<SEP>year']
# 6  ['Age<SEP>year', 'Age<SEP>year', 'year<SEP>Car...
# 7                   ['Age<SEP>year', 'Age<SEP>year']
# 8                   ['Age<SEP>year', 'Age<SEP>year']

# %%
df = agave.get_papers()

# %%
df.iloc[3].title
# Out:
# 'Risk factors for developing symptomatic COVID-19 in older residents of nursing homes: A hypothesis-generating observational study'
